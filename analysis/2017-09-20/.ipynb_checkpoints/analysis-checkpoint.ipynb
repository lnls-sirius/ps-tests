# %%
import matplotlib
import importlib as ilib
from ps_ramp_tests import analysis as a
fnames = [
    '/home/fac_files/lnls-sirius/ps-tests/data/test1_17-09-19_1459.txt',
    '/home/fac_files/lnls-sirius/ps-tests/data/test2_17-09-19_1501.txt',
    '/home/fac_files/lnls-sirius/ps-tests/data/test3_17-09-19_1502.txt',
]
fname = fnames[0]
matplotlib.rcParams.update({'font.size': 22})

# %% [markdown]
# # Read data from file, find trig borders and plot

# %%
data = a.read_data(fname=fname, print_flag=True)
# %matplotlib inline
a.plot_data(data)
data = a.add_sync_upborder(data, sync_sig_level=a._sync_sig_level)
# Out:
# sample rate   [kHz]  : 50.0
# number of points     : 500000
# time interval [s]    : 10.0
# number of signals    : 4
# index of sync signal : 3

# %% [markdown]
# # Split multiple ramps and compare them to reference curve

# %%
ilib.reload(a)
ramp_set = a.get_split_ramps_indices(data)
# %matplotlib qt5
a.plot_ramp_repeatibility(data, ramp_set)

# %%
matplotlib.rc('font')

# %%
c1 = data[ramp_set[0],0]
c2 = data[ramp_set[0],1]
c3 = data[ramp_set[0],2]
plt.plot(c1)
plt.plot(c2)
plt.plot(c3)
c1 = data[ramp_set[15],0]
c2 = data[ramp_set[15],1]
c3 = data[ramp_set[15],2]
plt.plot(c1)
plt.plot(c2)
plt.plot(c3)

plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib auto
plt.plot([1,2],[3,4])
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
# %matplotlib -l
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt', 'qt4', 'qt5', 'osx', 'nbagg', 'notebook', 'agg', 'inline', 'ipympl']

# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '2.0.2'
